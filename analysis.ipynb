# %% [markdown]
# # Career Path Analysis -- 5 Year Plan from 2025 to 2030
#
# ## Introduction
#
# As I approach a pivotal point in my career in early 2025, I find myself evaluating potential paths forward. Having spent 3.5 years as an Aerospace Engineer at GE Vernova and recently completing my MS in Aerospace Engineering from Georgia Tech in May 2024, I'm at a natural juncture to consider my next professional moves. This analysis explores different career trajectories over the next five years, from 2025 to 2030, to help inform my decision-making process.
#
# ## Simulation Details
# This analysis uses a custom Python-based simulation to model different career trajectories and their financial implications over a five-year period from 2025 to 2030.
#
# ### Inputs
# The simulator can consider any number of different career paths.
#
# For each path, the model accepts a series of annual compensation packages which include
# - Base salary
# - Performance bonus
# - Retirement benefits (employer match)
# - RSU grants
# - Location-specific tax implications:
#   - Federal income tax brackets
#   - State income tax
#   - Additional local tax where applicable
#
# ### Calculations
# The simulation performs several key calculations for each year:
#
# 1. **Tax Calculations**:
#    - Computes effective tax rates using multiple tax schedules (federal, state, and local)
#    - Applies progressive tax brackets for accurate tax burden estimation
#
# 2. **Compensation Processing**:
#    - Calculates after-tax income from multiple sources (salary, bonus, RSUs)
#    - Accounts for employer retirement contributions
#    - Factors in any one-time adjustments (e.g., grad school payments)
#
# 3. **Wealth Accumulation**:
#    - Tracks year-over-year wealth changes
#    - Maintains running total of net worth
#    - Records detailed compensation history
#
# ### Expected Results
# The simulation will provide:
# - Yearly compensation breakdowns by component (salary, bonus, RSUs)
# - Effective tax rates by location
# - Net worth progression over time
# - Total wealth accumulation by the end of 2029
#
# ### Assumptions
#
# #### Explicit Assumptions
#
# **Market Conditions:**
#    - RSU values remain stable
#    - Tax brackets are based on 2025 projections
#    - Existing wealth increases by an assumed real market growth rate annually (7% by default)
#
# #### Implicit Assumptions (Limitations)
#
# **The simulation doesn't account for:**
#    - Cost of living differences between locations
#    - Real estate market implications
#    - Potential market volatility affecting RSU values
#    - Non-financial factors (career growth, work-life balance)
#    - Additional benefits (health insurance, PTO, etc.)
#    - Potential changes in tax law or company policies
#    - Investment returns on accumulated wealth

# %%
# Run the simulation 
import colorsys
import pandas as pd
from config import run_simulation
import plotly.io as pio
pio.renderers.default='iframe'
from plotter import plot_total_wealth_progression, plot_annual_compensation, plot_tax_burden_comparison, plot_comprehensive_comparison

simulation_results = run_simulation()

# %% [markdown]
# ## The Financials
#
# ### Anticipated Career Path Inputs

# %%
# Formatting was done by Claude.ai because I've got better things to do than format a DataFrame.
def combine_dfs(df_dict: dict[int, pd.DataFrame]) -> pd.DataFrame:
    index_names = ['Category', 'Year']

    # Concatenate DataFrames
    combined_df = pd.concat(
        df_dict,
        keys=df_dict.keys(),
        names=index_names
    ).reorder_levels([index_names[1], index_names[0]])

    return combined_df

def create_styled_comparison_df(
    df: pd.DataFrame,
    format_dict: dict[str, str],
    caption: str = ""
):
    """
    Creates a styled DataFrame from a dictionary of DataFrames with consistent MultiIndex formatting.
    
    Parameters
    ----------
    df : pd.DataFrame
        DataFrame with a multiindex of Category and Year, created by combine_dfs()
    format_dict : dict, optional
        Dictionary of column names to format strings for styling
    caption : str, optional
        Caption for the table. Default is "".
    
    Returns
    -------
    pandas.io.formats.style.Styler
        Styled concatenated DataFrame
    """
    index_names = ['Category', 'Year']
    
    def highlight_categories(df: pd.DataFrame) -> pd.DataFrame:
        """
        Creates a style DataFrame that applies unique background colors to different categories in a MultiIndex DataFrame.
        
        Parameters
        ----------
        df : pd.DataFrame
           Input DataFrame with MultiIndex containing categories to highlight
           
        Returns
        -------
        pd.DataFrame
           DataFrame of same shape as input containing CSS style strings for background colors
           
        Notes
        -----
        Colors are generated using HSV color space with:
        - Evenly spaced hues based on number of categories
        - Fixed saturation of 0.15 for pastel colors
        - Fixed value of 1.0 for full brightness
        
        The function extracts unique categories from the first level of the MultiIndex 
        and assigns each a unique pastel color. Style strings are formatted as 
        'background-color: #RRGGBB' using hex color codes.
        """
        styles = pd.DataFrame('', index=df.index, columns=df.columns)
        categories = df.index.get_level_values(index_names[0]).unique()
        
        n_colors = len(categories)
        colors: dict[str, str] = {}
        for i, category in enumerate(categories):
           hue = i / n_colors
           saturation = 0.15
           value = 1.0
           
           rgb = colorsys.hsv_to_rgb(hue, saturation, value)
           hex_color = '#{:02x}{:02x}{:02x}'.format(
               int(rgb[0] * 255),
               int(rgb[1] * 255),
               int(rgb[2] * 255)
           )
           
           colors[category] = f'background-color: {hex_color}'
        
        for category, color in colors.items():
           styles.loc[(slice(None), category), :] = color
        
        return styles

    
    # Apply styling
    styled_df = (df
        .style
        .format(format_dict)
        .apply(highlight_categories, axis=None)
        .set_properties(**{
            'text-align': 'right',
            'padding': '5px',
            'border': '1px solid #ddd'
        })
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', '#f5f5f5'), 
                                       ('font-weight', 'bold'),
                                       ('text-align', 'left'),
                                       ('padding', '5px'),
                                       ('border', '1px solid #ddd')]},
            {'selector': 'caption', 'props': [('caption-side', 'bottom'), 
                                            ('font-style', 'italic')]}
        ])
        .set_caption(caption)
    )
    
    return styled_df


compensation_df = combine_dfs(simulation_results["compensation_histories"])
compensation_display = create_styled_comparison_df(
    compensation_df,
    format_dict = {
        'Salary': lambda x: f'${x/1000:.0f}K',
        'Bonus': lambda x: f'${x/1000:.0f}K',
        'RSU Grant': lambda x: f'${x/1000:.0f}K',
        'Retirement Match %': '{:.1%}',
        'Effective Tax Rate': '{:.1%}',
        'Income Adjustment': lambda x: f'${x/1000:.0f}K'
    },
    caption='Compensation Comparison Across Career Paths'
)
display(compensation_display)
# Out:
# <style type="text/css">
# #T_4623e th {
#   background-color: #f5f5f5;
#   font-weight: bold;
#   text-align: left;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_4623e caption {
#   caption-side: bottom;
#   font-style: italic;
# }
# #T_4623e_row0_col0, #T_4623e_row0_col1, #T_4623e_row0_col2, #T_4623e_row0_col3, #T_4623e_row0_col4, #T_4623e_row0_col5, #T_4623e_row0_col6, #T_4623e_row0_col7, #T_4623e_row0_col8, #T_4623e_row0_col9, #T_4623e_row1_col0, #T_4623e_row1_col1, #T_4623e_row1_col2, #T_4623e_row1_col3, #T_4623e_row1_col4, #T_4623e_row1_col5, #T_4623e_row1_col6, #T_4623e_row1_col7, #T_4623e_row1_col8, #T_4623e_row1_col9, #T_4623e_row2_col0, #T_4623e_row2_col1, #T_4623e_row2_col2, #T_4623e_row2_col3, #T_4623e_row2_col4, #T_4623e_row2_col5, #T_4623e_row2_col6, #T_4623e_row2_col7, #T_4623e_row2_col8, #T_4623e_row2_col9, #T_4623e_row3_col0, #T_4623e_row3_col1, #T_4623e_row3_col2, #T_4623e_row3_col3, #T_4623e_row3_col4, #T_4623e_row3_col5, #T_4623e_row3_col6, #T_4623e_row3_col7, #T_4623e_row3_col8, #T_4623e_row3_col9, #T_4623e_row4_col0, #T_4623e_row4_col1, #T_4623e_row4_col2, #T_4623e_row4_col3, #T_4623e_row4_col4, #T_4623e_row4_col5, #T_4623e_row4_col6, #T_4623e_row4_col7, #T_4623e_row4_col8, #T_4623e_row4_col9 {
#   background-color: #ffd8d8;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_4623e_row5_col0, #T_4623e_row5_col1, #T_4623e_row5_col2, #T_4623e_row5_col3, #T_4623e_row5_col4, #T_4623e_row5_col5, #T_4623e_row5_col6, #T_4623e_row5_col7, #T_4623e_row5_col8, #T_4623e_row5_col9, #T_4623e_row6_col0, #T_4623e_row6_col1, #T_4623e_row6_col2, #T_4623e_row6_col3, #T_4623e_row6_col4, #T_4623e_row6_col5, #T_4623e_row6_col6, #T_4623e_row6_col7, #T_4623e_row6_col8, #T_4623e_row6_col9, #T_4623e_row7_col0, #T_4623e_row7_col1, #T_4623e_row7_col2, #T_4623e_row7_col3, #T_4623e_row7_col4, #T_4623e_row7_col5, #T_4623e_row7_col6, #T_4623e_row7_col7, #T_4623e_row7_col8, #T_4623e_row7_col9, #T_4623e_row8_col0, #T_4623e_row8_col1, #T_4623e_row8_col2, #T_4623e_row8_col3, #T_4623e_row8_col4, #T_4623e_row8_col5, #T_4623e_row8_col6, #T_4623e_row8_col7, #T_4623e_row8_col8, #T_4623e_row8_col9, #T_4623e_row9_col0, #T_4623e_row9_col1, #T_4623e_row9_col2, #T_4623e_row9_col3, #T_4623e_row9_col4, #T_4623e_row9_col5, #T_4623e_row9_col6, #T_4623e_row9_col7, #T_4623e_row9_col8, #T_4623e_row9_col9 {
#   background-color: #d8ffd8;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_4623e_row10_col0, #T_4623e_row10_col1, #T_4623e_row10_col2, #T_4623e_row10_col3, #T_4623e_row10_col4, #T_4623e_row10_col5, #T_4623e_row10_col6, #T_4623e_row10_col7, #T_4623e_row10_col8, #T_4623e_row10_col9, #T_4623e_row11_col0, #T_4623e_row11_col1, #T_4623e_row11_col2, #T_4623e_row11_col3, #T_4623e_row11_col4, #T_4623e_row11_col5, #T_4623e_row11_col6, #T_4623e_row11_col7, #T_4623e_row11_col8, #T_4623e_row11_col9, #T_4623e_row12_col0, #T_4623e_row12_col1, #T_4623e_row12_col2, #T_4623e_row12_col3, #T_4623e_row12_col4, #T_4623e_row12_col5, #T_4623e_row12_col6, #T_4623e_row12_col7, #T_4623e_row12_col8, #T_4623e_row12_col9, #T_4623e_row13_col0, #T_4623e_row13_col1, #T_4623e_row13_col2, #T_4623e_row13_col3, #T_4623e_row13_col4, #T_4623e_row13_col5, #T_4623e_row13_col6, #T_4623e_row13_col7, #T_4623e_row13_col8, #T_4623e_row13_col9, #T_4623e_row14_col0, #T_4623e_row14_col1, #T_4623e_row14_col2, #T_4623e_row14_col3, #T_4623e_row14_col4, #T_4623e_row14_col5, #T_4623e_row14_col6, #T_4623e_row14_col7, #T_4623e_row14_col8, #T_4623e_row14_col9 {
#   background-color: #d8d8ff;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_4623e">
#   <caption>Compensation Comparison Across Career Paths</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4623e_level0_col0" class="col_heading level0 col0" >Company</th>
#       <th id="T_4623e_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_4623e_level0_col2" class="col_heading level0 col2" >Location</th>
#       <th id="T_4623e_level0_col3" class="col_heading level0 col3" >Salary</th>
#       <th id="T_4623e_level0_col4" class="col_heading level0 col4" >Bonus</th>
#       <th id="T_4623e_level0_col5" class="col_heading level0 col5" >Retirement Match %</th>
#       <th id="T_4623e_level0_col6" class="col_heading level0 col6" >RSU Grant</th>
#       <th id="T_4623e_level0_col7" class="col_heading level0 col7" >Effective Tax Rate</th>
#       <th id="T_4623e_level0_col8" class="col_heading level0 col8" >Income Adjustment</th>
#       <th id="T_4623e_level0_col9" class="col_heading level0 col9" >Comment</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="index_name level1" >Category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4623e_level0_row0" class="row_heading level0 row0" >2025</th>
#       <th id="T_4623e_level1_row0" class="row_heading level1 row0" >GE in SC</th>
#       <td id="T_4623e_row0_col0" class="data row0 col0" >GE</td>
#       <td id="T_4623e_row0_col1" class="data row0 col1" >PB Engineer</td>
#       <td id="T_4623e_row0_col2" class="data row0 col2" >SC</td>
#       <td id="T_4623e_row0_col3" class="data row0 col3" >$95K</td>
#       <td id="T_4623e_row0_col4" class="data row0 col4" >$5K</td>
#       <td id="T_4623e_row0_col5" class="data row0 col5" >7.0%</td>
#       <td id="T_4623e_row0_col6" class="data row0 col6" >$80K</td>
#       <td id="T_4623e_row0_col7" class="data row0 col7" >26.0%</td>
#       <td id="T_4623e_row0_col8" class="data row0 col8" >$0K</td>
#       <td id="T_4623e_row0_col9" class="data row0 col9" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4623e_level0_row1" class="row_heading level0 row1" >2026</th>
#       <th id="T_4623e_level1_row1" class="row_heading level1 row1" >GE in SC</th>
#       <td id="T_4623e_row1_col0" class="data row1 col0" >GE</td>
#       <td id="T_4623e_row1_col1" class="data row1 col1" >LPB Engineer</td>
#       <td id="T_4623e_row1_col2" class="data row1 col2" >SC</td>
#       <td id="T_4623e_row1_col3" class="data row1 col3" >$102K</td>
#       <td id="T_4623e_row1_col4" class="data row1 col4" >$10K</td>
#       <td id="T_4623e_row1_col5" class="data row1 col5" >7.0%</td>
#       <td id="T_4623e_row1_col6" class="data row1 col6" >$0K</td>
#       <td id="T_4623e_row1_col7" class="data row1 col7" >23.4%</td>
#       <td id="T_4623e_row1_col8" class="data row1 col8" >$0K</td>
#       <td id="T_4623e_row1_col9" class="data row1 col9" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4623e_level0_row2" class="row_heading level0 row2" >2027</th>
#       <th id="T_4623e_level1_row2" class="row_heading level1 row2" >GE in SC</th>
#       <td id="T_4623e_row2_col0" class="data row2 col0" >GE</td>
#       <td id="T_4623e_row2_col1" class="data row2 col1" >LPB Engineer</td>
#       <td id="T_4623e_row2_col2" class="data row2 col2" >SC</td>
#       <td id="T_4623e_row2_col3" class="data row2 col3" >$105K</td>
#       <td id="T_4623e_row2_col4" class="data row2 col4" >$10K</td>
#       <td id="T_4623e_row2_col5" class="data row2 col5" >7.0%</td>
#       <td id="T_4623e_row2_col6" class="data row2 col6" >$80K</td>
#       <td id="T_4623e_row2_col7" class="data row2 col7" >26.4%</td>
#       <td id="T_4623e_row2_col8" class="data row2 col8" >$0K</td>
#       <td id="T_4623e_row2_col9" class="data row2 col9" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4623e_level0_row3" class="row_heading level0 row3" >2028</th>
#       <th id="T_4623e_level1_row3" class="row_heading level1 row3" >GE in SC</th>
#       <td id="T_4623e_row3_col0" class="data row3 col0" >GE</td>
#       <td id="T_4623e_row3_col1" class="data row3 c

# %% [markdown]
# ## Simulation Results

# %%
worth_df = combine_dfs(simulation_results["worth_histories"])
worth_display = create_styled_comparison_df(
    worth_df,
    format_dict = {
        # Regular numbers
        'Retirement Match %': '{:.1%}',
        'Effective Tax Rate': '{:.1%}',
        
        # Dollar amounts in thousands
        'Gross Salary': lambda x: f'${x/1000:.0f}K',
        'Gross Bonus': lambda x: f'${x/1000:.0f}K',
        'Gross RSUs': lambda x: f'${x/1000:.0f}K',
        'Gross Income': lambda x: f'${x/1000:.0f}K',
        'Net Salary': lambda x: f'${x/1000:.0f}K',
        'Net Bonus': lambda x: f'${x/1000:.0f}K',
        'Net RSUs': lambda x: f'${x/1000:.0f}K',
        'Retirement Match': lambda x: f'${x/1000:.0f}K',
        'Income Adjustment': lambda x: f'${x/1000:.0f}K',
        'Net Income': lambda x: f'${x/1000:.0f}K',
        'Total Tax Burden': lambda x: f'${x/1000:.0f}K',
        'Unrealized Investment Gain': lambda x: f'${x/1000:.0f}K',
        'Total Earned Wealth': lambda x: f'${x/1000:.0f}K',
        
        # Text fields don't need formatting
        # 'Company': None,
        # 'Title': None,
        # 'Location': None,
        # 'Comment': None
    },
    caption='Wealth Progression Across Career Paths'
)
display(worth_display)
# Out:
# <style type="text/css">
# #T_39ceb th {
#   background-color: #f5f5f5;
#   font-weight: bold;
#   text-align: left;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_39ceb caption {
#   caption-side: bottom;
#   font-style: italic;
# }
# #T_39ceb_row0_col0, #T_39ceb_row0_col1, #T_39ceb_row0_col2, #T_39ceb_row0_col3, #T_39ceb_row0_col4, #T_39ceb_row0_col5, #T_39ceb_row0_col6, #T_39ceb_row0_col7, #T_39ceb_row0_col8, #T_39ceb_row0_col9, #T_39ceb_row0_col10, #T_39ceb_row0_col11, #T_39ceb_row0_col12, #T_39ceb_row0_col13, #T_39ceb_row0_col14, #T_39ceb_row0_col15, #T_39ceb_row0_col16, #T_39ceb_row0_col17, #T_39ceb_row0_col18, #T_39ceb_row1_col0, #T_39ceb_row1_col1, #T_39ceb_row1_col2, #T_39ceb_row1_col3, #T_39ceb_row1_col4, #T_39ceb_row1_col5, #T_39ceb_row1_col6, #T_39ceb_row1_col7, #T_39ceb_row1_col8, #T_39ceb_row1_col9, #T_39ceb_row1_col10, #T_39ceb_row1_col11, #T_39ceb_row1_col12, #T_39ceb_row1_col13, #T_39ceb_row1_col14, #T_39ceb_row1_col15, #T_39ceb_row1_col16, #T_39ceb_row1_col17, #T_39ceb_row1_col18, #T_39ceb_row2_col0, #T_39ceb_row2_col1, #T_39ceb_row2_col2, #T_39ceb_row2_col3, #T_39ceb_row2_col4, #T_39ceb_row2_col5, #T_39ceb_row2_col6, #T_39ceb_row2_col7, #T_39ceb_row2_col8, #T_39ceb_row2_col9, #T_39ceb_row2_col10, #T_39ceb_row2_col11, #T_39ceb_row2_col12, #T_39ceb_row2_col13, #T_39ceb_row2_col14, #T_39ceb_row2_col15, #T_39ceb_row2_col16, #T_39ceb_row2_col17, #T_39ceb_row2_col18, #T_39ceb_row3_col0, #T_39ceb_row3_col1, #T_39ceb_row3_col2, #T_39ceb_row3_col3, #T_39ceb_row3_col4, #T_39ceb_row3_col5, #T_39ceb_row3_col6, #T_39ceb_row3_col7, #T_39ceb_row3_col8, #T_39ceb_row3_col9, #T_39ceb_row3_col10, #T_39ceb_row3_col11, #T_39ceb_row3_col12, #T_39ceb_row3_col13, #T_39ceb_row3_col14, #T_39ceb_row3_col15, #T_39ceb_row3_col16, #T_39ceb_row3_col17, #T_39ceb_row3_col18, #T_39ceb_row4_col0, #T_39ceb_row4_col1, #T_39ceb_row4_col2, #T_39ceb_row4_col3, #T_39ceb_row4_col4, #T_39ceb_row4_col5, #T_39ceb_row4_col6, #T_39ceb_row4_col7, #T_39ceb_row4_col8, #T_39ceb_row4_col9, #T_39ceb_row4_col10, #T_39ceb_row4_col11, #T_39ceb_row4_col12, #T_39ceb_row4_col13, #T_39ceb_row4_col14, #T_39ceb_row4_col15, #T_39ceb_row4_col16, #T_39ceb_row4_col17, #T_39ceb_row4_col18 {
#   background-color: #ffd8d8;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_39ceb_row5_col0, #T_39ceb_row5_col1, #T_39ceb_row5_col2, #T_39ceb_row5_col3, #T_39ceb_row5_col4, #T_39ceb_row5_col5, #T_39ceb_row5_col6, #T_39ceb_row5_col7, #T_39ceb_row5_col8, #T_39ceb_row5_col9, #T_39ceb_row5_col10, #T_39ceb_row5_col11, #T_39ceb_row5_col12, #T_39ceb_row5_col13, #T_39ceb_row5_col14, #T_39ceb_row5_col15, #T_39ceb_row5_col16, #T_39ceb_row5_col17, #T_39ceb_row5_col18, #T_39ceb_row6_col0, #T_39ceb_row6_col1, #T_39ceb_row6_col2, #T_39ceb_row6_col3, #T_39ceb_row6_col4, #T_39ceb_row6_col5, #T_39ceb_row6_col6, #T_39ceb_row6_col7, #T_39ceb_row6_col8, #T_39ceb_row6_col9, #T_39ceb_row6_col10, #T_39ceb_row6_col11, #T_39ceb_row6_col12, #T_39ceb_row6_col13, #T_39ceb_row6_col14, #T_39ceb_row6_col15, #T_39ceb_row6_col16, #T_39ceb_row6_col17, #T_39ceb_row6_col18, #T_39ceb_row7_col0, #T_39ceb_row7_col1, #T_39ceb_row7_col2, #T_39ceb_row7_col3, #T_39ceb_row7_col4, #T_39ceb_row7_col5, #T_39ceb_row7_col6, #T_39ceb_row7_col7, #T_39ceb_row7_col8, #T_39ceb_row7_col9, #T_39ceb_row7_col10, #T_39ceb_row7_col11, #T_39ceb_row7_col12, #T_39ceb_row7_col13, #T_39ceb_row7_col14, #T_39ceb_row7_col15, #T_39ceb_row7_col16, #T_39ceb_row7_col17, #T_39ceb_row7_col18, #T_39ceb_row8_col0, #T_39ceb_row8_col1, #T_39ceb_row8_col2, #T_39ceb_row8_col3, #T_39ceb_row8_col4, #T_39ceb_row8_col5, #T_39ceb_row8_col6, #T_39ceb_row8_col7, #T_39ceb_row8_col8, #T_39ceb_row8_col9, #T_39ceb_row8_col10, #T_39ceb_row8_col11, #T_39ceb_row8_col12, #T_39ceb_row8_col13, #T_39ceb_row8_col14, #T_39ceb_row8_col15, #T_39ceb_row8_col16, #T_39ceb_row8_col17, #T_39ceb_row8_col18, #T_39ceb_row9_col0, #T_39ceb_row9_col1, #T_39ceb_row9_col2, #T_39ceb_row9_col3, #T_39ceb_row9_col4, #T_39ceb_row9_col5, #T_39ceb_row9_col6, #T_39ceb_row9_col7, #T_39ceb_row9_col8, #T_39ceb_row9_col9, #T_39ceb_row9_col10, #T_39ceb_row9_col11, #T_39ceb_row9_col12, #T_39ceb_row9_col13, #T_39ceb_row9_col14, #T_39ceb_row9_col15, #T_39ceb_row9_col16, #T_39ceb_row9_col17, #T_39ceb_row9_col18 {
#   background-color: #d8ffd8;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# #T_39ceb_row10_col0, #T_39ceb_row10_col1, #T_39ceb_row10_col2, #T_39ceb_row10_col3, #T_39ceb_row10_col4, #T_39ceb_row10_col5, #T_39ceb_row10_col6, #T_39ceb_row10_col7, #T_39ceb_row10_col8, #T_39ceb_row10_col9, #T_39ceb_row10_col10, #T_39ceb_row10_col11, #T_39ceb_row10_col12, #T_39ceb_row10_col13, #T_39ceb_row10_col14, #T_39ceb_row10_col15, #T_39ceb_row10_col16, #T_39ceb_row10_col17, #T_39ceb_row10_col18, #T_39ceb_row11_col0, #T_39ceb_row11_col1, #T_39ceb_row11_col2, #T_39ceb_row11_col3, #T_39ceb_row11_col4, #T_39ceb_row11_col5, #T_39ceb_row11_col6, #T_39ceb_row11_col7, #T_39ceb_row11_col8, #T_39ceb_row11_col9, #T_39ceb_row11_col10, #T_39ceb_row11_col11, #T_39ceb_row11_col12, #T_39ceb_row11_col13, #T_39ceb_row11_col14, #T_39ceb_row11_col15, #T_39ceb_row11_col16, #T_39ceb_row11_col17, #T_39ceb_row11_col18, #T_39ceb_row12_col0, #T_39ceb_row12_col1, #T_39ceb_row12_col2, #T_39ceb_row12_col3, #T_39ceb_row12_col4, #T_39ceb_row12_col5, #T_39ceb_row12_col6, #T_39ceb_row12_col7, #T_39ceb_row12_col8, #T_39ceb_row12_col9, #T_39ceb_row12_col10, #T_39ceb_row12_col11, #T_39ceb_row12_col12, #T_39ceb_row12_col13, #T_39ceb_row12_col14, #T_39ceb_row12_col15, #T_39ceb_row12_col16, #T_39ceb_row12_col17, #T_39ceb_row12_col18, #T_39ceb_row13_col0, #T_39ceb_row13_col1, #T_39ceb_row13_col2, #T_39ceb_row13_col3, #T_39ceb_row13_col4, #T_39ceb_row13_col5, #T_39ceb_row13_col6, #T_39ceb_row13_col7, #T_39ceb_row13_col8, #T_39ceb_row13_col9, #T_39ceb_row13_col10, #T_39ceb_row13_col11, #T_39ceb_row13_col12, #T_39ceb_row13_col13, #T_39ceb_row13_col14, #T_39ceb_row13_col15, #T_39ceb_row13_col16, #T_39ceb_row13_col17, #T_39ceb_row13_col18, #T_39ceb_row14_col0, #T_39ceb_row14_col1, #T_39ceb_row14_col2, #T_39ceb_row14_col3, #T_39ceb_row14_col4, #T_39ceb_row14_col5, #T_39ceb_row14_col6, #T_39ceb_row14_col7, #T_39ceb_row14_col8, #T_39ceb_row14_col9, #T_39ceb_row14_col10, #T_39ceb_row14_col11, #T_39ceb_row14_col12, #T_39ceb_row14_col13, #T_39ceb_row14_col14, #T_39ceb_row14_col15, #T_39ceb_row14_col16, #T_39ceb_row14_col17, #T_39ceb_row14_col18 {
#   background-color: #d8d8ff;
#   text-align: right;
#   padding: 5px;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_39ceb">
#   <caption>Wealth Progression Across Career Paths</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39ceb_level0_col0" class="col_heading level0 col0" >Company</th>
#       <th id="T_39ceb_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_39ceb_level0_col2" class="col_heading level0 col2" >Location</th>
#       <th id="T_39ceb_level0_col3" class="col_heading level0 col3" >Comment</th>
#       <th id="T_39ceb_level0_col4" class="col_heading level0 col4" >Gross Salary</th>
#       <th id="T_39ceb_level0_col5" class="col_heading level0 col5" >Gross Bonus</th>
#       <th id="T_39ceb_level0_col6" class="col_heading level0 col6" >Gross RSUs</th>
#       <th id="T_39ceb_level0_col7" class="col_heading level0 col7" >Retirement Match %</th>
#       <th id="T_39ceb_level0_col8" class="col_heading level0 col8" >Gross Income</th>
#       <th id="T_39ceb_level0_col9" class="col_heading level0 col9" >Effective Tax Rate</th>
#       <th id="T_39ceb_level0_col10" class="col_heading level0 col10" >Total Tax Burden</th>
#       <th id="T_39ceb_level0_col11" class="col_heading level0 col11" >Net Salary</th>
#       <th id="T_39ceb_level0_col12" class="col_heading level0 col12" >Net Bonus</th>
#       <th id="T_39ceb_level0_col13" class="col_heading level0 col13" >Net RSUs</th>
#       <th id="T_39ceb_level0_col14" class="col_heading level0 col14" >Retirement Match</th>
#       <th id="T_39ceb_level0_col15" class="col_heading level0 col15" >Income Adjustment</

# %%
# Individual plots
wealth_fig = plot_total_wealth_progression(worth_df)
# tax_fig = plot_tax_burden_comparison(worth_df)

# Comprehensive comparison
# comp_fig = plot_comprehensive_comparison(worth_df)

# Display in notebook
wealth_fig.show()
# tax_fig.show()
# comp_fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_4.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
comp_fig = plot_annual_compensation(worth_df)
comp_fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1720px"
#     height="1020"
#     src="iframe_figures/figure_5.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
